# %%
import turicreate

# %%
Books=turicreate.SFrame('/content/sample_data/book selection-1.csv')
# Out:
# Read 100 lines. Lines per second: 1175.2
# Finished parsing file /content/sample_data/book selection-1.csv
# Parsing completed. Parsed 100 lines in 0.092967 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,str,str,str,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /content/sample_data/book selection-1.csv
# Parsing completed. Parsed 1058 lines in 0.038867 secs.

# %%
train_data,test_data=Books.random_split(.8,seed=0)

# %%
books_recommender=turicreate.item_similarity_recommender.create(train_data,user_id='1. Name',item_id='2. select book')
# Out:
# ...
#  To use one of these as a rating column, specify the column name to be used as target
#     and use a method that allows the use of a target.
# Preparing data set.
#     Data has 843 observations with 498 users and 27 items.
#     Data prepared in: 0.016955s

# %%
users=Books['1. Name'].unique()
# Out:
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 1.358ms                        | 100        |

# %%
users
# Out:
# +--------------------------------+------------+
# dtype: str
# Rows: 541
# ...

# %%
# Out:
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+

# %%
books_recommender.recommend(users=['P Hemanth'],k=5).head()
# Out:
# | 1.813ms                             | 0                | 0               |
# | 2.205ms                             | 100              | 27              |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 0.006787s
# Columns:
# 	1. Name	str
# 	2. select book	str
# 	score	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-----------+--------------------------------+----------------------+------+
# |  1. Name  |         2. select book         |        score         | rank |
# +-----------+--------------------------------+----------------------+------+
# | P Hemanth | Machine learning for beginners | 0.12727272510528564  |  1   |
# | P Hemanth | Hands on Machine Learning ...  | 0.10344827175140381  |  2   |
# | P Hemanth |  Machine learning with python  |  0.0724637508392334  |  3   |
# ...
